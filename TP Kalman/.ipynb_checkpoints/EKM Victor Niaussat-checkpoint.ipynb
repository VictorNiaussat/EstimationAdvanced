# %%
import numpy as np
from scipy import signal,stats
import pykalman as pk
from matplotlib import pyplot as plt
import pandas as pd

# %%
df = pd.read_excel("./2223G3-SDIA-donnees.xlsx",index_col="Temps")[["signalReel","signalBruite"]]
df.loc[:0.5].plot()

z= df.signalBruite.to_numpy()
N=len(z)

# %%
Q = np.array([[2e-5,0],[0,2e-1]])

R = 3

A = np.eye(2)

phi = 0
f_0 = 12
f_e = 123.28
Te = 1/123.28
a = 5

h = lambda x: a*np.sin(2*np.pi*f_0*Te+phi)

# %%
w = np.random.normal(loc=0.0, scale=R)
v = np.random.normal(loc=0.0, scale=R)

# %%
H = lambda k : np.array([np.sin(2*np.pi*f_0*Te+phi),a*np.cos(2*np.pi*f_0*Te+phi)])
f = lambda x:x
F = lambda k: np.zeros((2,2))

# %%
import pdb

# %%
def EKM(z):
    N = len(z)
    x = np.array([a,phi])
    P = A
    k = 0
    X = [x.tolist()]
    while k<N-1 :
        w = np.random.normal(loc=0.0, scale=R)
        v = np.random.normal(loc=0.0, scale=np.diag(Q))
        
        x = f(x) + v
        
        P = F(k)@P@F(k).T + Q
        k += 1
        S = H(k)@P@H(k).T + R
        
        K = P@H(k).T/S
        z_hat = h(x)
        eps = z[k] - z_hat
        x = x + eps*K.T
        P = P - S*K@K.T
        
        X.append(x.tolist())
        
    return(X)

# %%
x_hat = EKM(z)

# %%
x_hat[-4:]
# Out:
# [[4.8951751933318945, -7339.7086491916425],
#  [4.895195282598285, -7340.336110146018],
#  [4.895178620522894, -7341.0231080603535],
#  [4.895124643049295, -7342.230026372964]]

# %%
plt.plot(x_hat)
# Out:
# [<matplotlib.lines.Line2D at 0x2341d987fa0>,
#  <matplotlib.lines.Line2D at 0x2341d98be80>]
